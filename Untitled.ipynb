# %%
data = ''
with open('SF7Turns.txt', 'r') as myfile:
  data = myfile.read().replace('\n',' ')

# %%
import re
#data[0:12000]

# %%
moves = re.findall('.*? \[EndMove\]',data)

# %%
print(len(moves), '\n', moves[1][0:1000])
# Out:
# 9027
# ...

# %%
move_num = re.findall('Turn.*?(\d+)', moves[1])
move_col = re.findall('Turn "\d+-(\w)"', moves[1])
year = re.findall(';.*?(\d+).',moves[1])
nlegal = re.findall('NumLegalMoves.*?(\d+)',moves[1])
evaln = re.findall('\[Eval ".*?(\d+)',moves[1])
prev_evaln = re.findall('\[PrevEval ".*?(\d+)',moves[1])
next_evaln = re.findall('\[NextEval ".*?(\d+)',moves[1])
FEN = re.findall('\[FEN "(.*?)"]',moves[1])
elos = re.findall('Elo.*?(\d+)',data)
elos
# Out:
# ['2763',
#  '2788',
#  '2707',
#  '2670',
#  '2735',
#  '2788',
#  '2738',
#  '2719',
#  '2719',
#  '2735',
#  '2670',
#  '2738',
#  '2763',
#  '2707',
#  '2788',
#  '2788',
#  '2788',
#  '2719',
#  '2707',
#  '2788',
#  '2735',
#  '2670',
#  '2738',
#  '2763',
#  '2670',
#  '2788',
#  '2763',
#  '2735',
#  '2707',
#  '2738',
#  '2788',
#  '2719',
#  '2719',
#  '2670',
#  '2788',
#  '2763',
#  '2735',
#  '2707',
#  '2738',
#  '2788',
#  '2719',
#  '2707',
#  '2788',
#  '2738',
#  '2670',
#  '2763',
#  '2735',
#  '2788',
#  '2763',
#  '2719',
#  '2707',
#  '2788',
#  '2738',
#  '2735',
#  '2788',
#  '2670',
#  '2719',
#  '2738',
#  '2788',
#  '2735',
#  '2670',
#  '2707',
#  '2788',
#  '2763',
#  '2788',
#  '2788',
#  '2707',
#  '2763',
#  '2735',
#  '2719',
#  '2738',
#  '2670',
#  '2719',
#  '2788',
#  '2670',
#  '2735',
#  '2763',
#  '2738',
#  '2788',
#  '2707',
#  '2719',
#  '2788',
#  '2788',
#  '2670',
#  '2735',
#  '2763',
#  '2738',
#  '2707',
#  '2670',
#  '2719',
# ...

# %%
cnt = 0
for i in moves:
    if(len(re.findall('Elo',i))):
        cnt+=1
cnt
# Out:
# 134
